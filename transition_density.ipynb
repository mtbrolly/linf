# %% [markdown]
# # Visualising the transition density

# %% [markdown]
# This notebook allows the user to plot the transition density for a given initial position using a simple function.

# %%
from dx.utils import plot_transition_density

# %%
plot_transition_density(X0=(-74.5, 34.85))

# %%
plot_transition_density(X0=(-60., 42.))

# %%
plot_transition_density(X0=(-48., 39.))
